# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist

# %%
# load data
X =np.load('data/f4/updated_inputs.npy')
y=np.load('data/f4/updated_outputs.npy')

# %%
# compute mean distance between data
distances = pdist(X, metric='euclidean')

# %%
# Grid for evaluation
from scipy.stats import qmc

dim=4
n_grid = 5000 
sampler = qmc.LatinHypercube(d=dim, seed=42)
sample = sampler.random(n=n_grid)

# Define bounds
l_bounds = X.min(axis=0)  
u_bounds = X.max(axis=0)  
x_grid_d = qmc.scale(sample, l_bounds, u_bounds)

# %%
# EI
xi=0.1
def expected_improvement(mean, std, best_f, xi):
    Z  = (mean - best_f - xi) / (std + 1e-9)
    ei = (mean - best_f - xi) * norm.cdf(Z) + std * norm.pdf(Z)
    ei[std <= 0.0] = 0.0
    return ei

# %%
# Normalization
y_mean_val = np.mean(y)
y_std_val  = np.std(y)
y_norm    = (y - y_mean_val) / y_std_val if y_std_val > 0 else y

# %%
# The current best
best_f = np.max(y_norm)
best_idx = np.argmax(y_norm)
print(f"Mejor observación actual: X = {X[best_idx]}, y_norm = {best_f:.4f}")
# Out:
# Mejor observación actual: X = [0.483343 0.342411 0.320498 0.440285], y_norm = 1.9237

# %%
# compute best rbf lengthscale
noise_assumption = 1e-5
Alpha=[]
Mean=[]
STD=[]
for alpha in np.linspace(0.1, 3, 30):
    rbf_lengthscale  = alpha*distances.mean()#alpha times mean distance

    kernel = RBF(length_scale=rbf_lengthscale, length_scale_bounds='fixed')
    model  = GaussianProcessRegressor(kernel=kernel, alpha=noise_assumption)
    model.fit(X, y_norm)

    # GP prediction ---
    post_mean, post_std = model.predict(x_grid_d, return_std=True)

    ei_values = expected_improvement(post_mean, post_std, best_f, xi)

    # The next point
    idx_next  = np.argmax(ei_values)# simple grid
    x_next    = x_grid_d[idx_next]
    # print(f"Suggested query (EI): x1={x_next[0]:.8f}, x2={x_next[1]:.8f}, x3={x_next[2]:.8f}, x3={x_next[3]:.8f}")
    # print('mean next=',post_mean[idx_next])
    # print('std next=',post_std[idx_next])
    Alpha.append(alpha)
    Mean.append(post_mean[idx_next])
    STD.append(post_std[idx_next])

# %%
# identify best alpha
id_max = np.argmax(Mean)
plt.plot(Alpha,Mean, label='Mean')
plt.plot(Alpha,STD, label='StD')
plt.plot(Alpha[id_max], Mean[id_max], marker='*')
plt.xlabel('alpha')
plt.legend()

print('Alpha for max mean=',Alpha[id_max])
# Out:
# Alpha for max mean= 1.8

# %%
# re-compute maximum
alpha=Alpha[id_max]
rbf_lengthscale  = alpha*distances.mean()#max mean distance
kernel = RBF(length_scale=rbf_lengthscale, length_scale_bounds='fixed')
model  = GaussianProcessRegressor(kernel=kernel, alpha=noise_assumption)
model.fit(X, y_norm)

# GP prediction ---
post_mean, post_std = model.predict(x_grid_d, return_std=True)
ei_values = expected_improvement(post_mean, post_std, best_f, xi=0.01)

# The next point
idx_next  = np.argmax(ei_values)# simple grid
x_next    = x_grid_d[idx_next]
std_next = post_std[idx_next]
y_next = post_mean[idx_next]#Next Point
print(f"Suggested query (EI): x1={x_next[0]:.8f}, x2={x_next[1]:.8f}, x3={x_next[2]:.8f}, x3={x_next[3]:.8f}")
print('mean next=',y_next)
print('std next=',std_next)

#query from EI
x_next_ei = x_next
y_next_ei = y_next
# Out:
# Suggested query (EI): x1=0.34953059, x2=0.33192977, x3=0.31763402, x3=0.39583252
# mean next= 1.946637168851339
# std next= 0.003068868216704054

# %%
# UCB acquisition: best k
K=[]
Mean=[]
STD=[]
for k in np.linspace(0.1, 3, 30):
    #UCB (maximize)
    # The next point
    acquisition = post_mean + k * post_std
    idx_next = np.argmax(acquisition)
    x_next = x_grid_d[idx_next]
    K.append(k)
    Mean.append(post_mean[idx_next])
    STD.append(post_std[idx_next])

# %%
# plot k optimization
id_max = np.argmax(Mean)
plt.plot(K,Mean, label='Mean')
plt.plot(K,STD, label='StD')
plt.plot(K[id_max], Mean[id_max], marker='*')
plt.xlabel('k')
plt.legend()

print('K for max mean=',K[id_max])
# Out:
# K for max mean= 0.1

# %%
# re-compute maximum
acquisition = post_mean + K[id_max] * post_std
idx_next = np.argmax(acquisition)
x_next = x_grid_d[idx_next]
std_next = post_std[idx_next]
y_next = post_mean[idx_next]
   
print(f"Suggested query (UCB): x1={x_next[0]:.8f}, x2={x_next[1]:.8f}, x3={x_next[2]:.8f}, x4={x_next[3]:.8f}")
print('mean next=',post_mean[idx_next])
print('std next=',post_std[idx_next])

#query from UCB
x_next_ucb = x_next
y_next_ucb = y_next
# Out:
# Suggested query (UCB): x1=0.34953059, x2=0.33192977, x3=0.31763402, x4=0.39583252
# mean next= 1.946637168851339
# std next= 0.003068868216704054

# %%
# RSM Method
import pandas as pd
from statsmodels.formula.api import ols

# %%
# create dataframe
data = np.column_stack((X,y))
df = pd.DataFrame(data, columns=['x1', 'x2', 'x3', 'x4', 'y'])
# fit regression model
model = ols(formula='y ~ x1 + x2 + x3 + x4 + I(x1**2) + I(x2**2) + I(x3**2) + I(x4**2)', data=df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.988
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                     243.6
# Date:                Sun, 13 Sep 2026   Prob (F-statistic):           2.31e-20
# Time:                        11:06:48   Log-Likelihood:                -39.795
# No. Observations:                  32   AIC:                             97.59
# Df Residuals:                      23   BIC:                             110.8
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -27.6846      1.219    -22.712      0.000     -30.206     -25.163
# x1            32.5744      3.402      9.576      0.000      25.537      39.611
# x2            31.8450      2.796     11.388      0.000      26.060      37.630
# x3            29.4971      4.067      7.253      0.000      21.084      37.910
# x4            31.3024      3.072     10.189      0.000      24.947      37.658
# I(x1 ** 2)   -40.4640      3.146    -12.863      0.000     -46.972     -33.956
# I(x2 ** 2)   -39.7446      2.921    -13.606      0.000     -45.787     -33.702
# I(x3 ** 2)   -38.6519      4.003     -9.655      0.000     -46.934     -30.370
# I(x4 ** 2)   -38.7900      3.046    -12.734      0.000     -45.092     -32.488
# ==============================================================================
# Omnibus:                        1.139   Durbin-Watson:                   2.301
# Prob(Omnibus):                  0.566   Jarque-Bera (JB):                0.581
# Skew:                           0.327   Prob(JB):                        0.748
# Kurtosis:                       3.092   Cond. No.                         60.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Optimization (Gradient Descent - Simplified)
from scipy.optimize import minimize

def objective(Xin):
    x1, x2, x3, x4 = Xin
    return -model.predict(pd.DataFrame({'x1': [x1], 'x2': [x2], 'x3': [x3], 'x4': [x4]}))[0]

initial_guess = X[best_idx] #starting from best current value
print('X best=',X[best_idx])
result = minimize(objective, initial_guess, bounds=[(0, 1.), (0, 1.), (0, 1.), (0, 1.)], method='L-BFGS-B')
optimal = result.x
print('optimal=',optimal)
print('objective (y)=',-objective(optimal))

#query from RSM
x_next_rsm = optimal
y_next_rsm = -objective(optimal)
# Out:
# X best= [0.483343 0.342411 0.320498 0.440285]
# optimal= [0.40251165 0.40062001 0.38157382 0.40348533]
# objective (y)= -2.8072706952882633

# %%
# Choose the best option between EI, UCB and RSM
if y_next_ei >= y_next_ucb and y_next_ei >= y_next_rsm:
    x_next_out = x_next_ei
elif y_next_ucb > y_next_ei and y_next_ucb > y_next_rsm:
    x_next_out = x_next_ucb
else:
    x_next_out = x_next_rsm

# Write output file
import os
folder = 'results'
filename = 'output_F4.txt'
file_path = os.path.join(folder, filename)
with open(file_path, 'w', encoding='utf-8') as f:
    f.write(f"{x_next_out[0]:.6f} {x_next_out[1]:.6f} {x_next_out[2]:.6f} {x_next_out[3]:.6f}\n")
